# %%
import torch
import torch.nn as nn

# %%
input = torch.tensor([[[[10, 10.0000, 5,   0.0000, 0.0000, 0.0000],
          [0.0000, 0.4410, 0.0000,   0.0000, 0.0000, 0.0000],
          [0.0000, 0.0000, 0.0000,   0.0000, 0.0000, 0.0000],
          
          [0.0000, 0.0000, 0.0000,   0.0000, 0.0000, 0.0000],
          [0.0000, 0.0000, 0.0000,   0.0000, 0.2562, 0.0000],
          [0.0000, 0.0000, 0.0000,   0.0000, 0.0000, 0.0000]],

         [[0.0000, 0.0000, 0.0000,   0.0000, 0.0000, 0.0000],
          [2.0132, 1.0354, 0.0000,   0.0000, 0.0000, 0.0000],
          [0.3857, 0.0000, 0.1801,   0.0000, 0.0000, 0.0000],
          
          [2.7994, 3.3148, 1.5957,   1.4995, 2.8311, 2.5134],
          [0.0000, 1.3019, 1.5223,   0.3723, 1.8744, 1.4663],
          [0.0000, 0.0000, 0.0000,   0.2828, 0.0000, 0.0000]],

         [[0.0000, 0.0000, 0.0000,   0.0000, 0.0000, 0.0000],
          [0.0000, 0.0000, 0.0000,   0.0000, 0.0000, 0.0000],
          [0.0000, 0.0000, 0.0000,   0.0000, 0.0000, 0.0000],
          
          [0.0000, 0.0000, 0.0000,   0.0000, 0.0000, 0.0000],
          [0.6144, 0.3670, 0.0000,   0.0000, 0.0000, 0.0000],
          [0.0000, 0.0000, 0.0000,   0.0000, 0.0000, 0.0000]],

         

         [[0.0000, 0.0000, 6.0000,   6, 0.0000, 0.0000],
          [0.0000, 2.2975, 0.0000,   0.0000, 0.0000, 0.2153],
          [0.0000, 1.8645, 0.0000,   0.0000, 0.0000, 0.0000],
          
          [1.3304, 0.6114, 0.7940,   0.0000, 0.0000, 0.0000],
          [5.8138, 3.8091, 0.6860,   0.0000, 0.0000, 0.0000],
          [0.0000, 0.0000, 0.0000,   0.7999, 0.0000, 0.0000]],

         [[0.0000, 0.0000, 0.0000,   0.0000, 0.0000, 0.0000],
          [0.0000, 0.0000, 0.0000,   0.0000, 0.0000, 0.0000],
          [0.0000, 0.0000, 0.0000,   0.0000, 0.0000, 0.0000],
          
          [0.0000, 0.0000, 0.0290,   0.0000, 0.0000, 0.0000],
          [0.0000, 0.0000, 0.0000,   0.0000, 0.0000, 0.0000],
          [0.0000, 0.0000, 0.0000,   0.0000, 0.1629, 0.9383]],

         [[0.0000, 0.0000, 0.0000,   0.0000, 0.0000, 0.0000],
          [0.0000, 0.0000, 0.0000,   0.0000, 0.0000, 0.0000],
          [0.0000, 0.0000, 0.0000,   0.0000, 0.0000, 0.0000],
          
          [0.0000, 0.0000, 0.0000,   0.0000, 0.0000, 0.0000],
          [0.2174, 0.9764, 0.0000,   0.0000, 0.0000, 0.0000],
          [0.0000, 0.2185, 0.2086,   0.0000, 0.0000, 0.0000]]]])

# %%
input_start.size()
# Out:
# torch.Size([1, 6, 6, 6])

# %%
n, c, w, h = input.size()

# %%
input2 = input.view(n,c,w*h).permute(0,2,1)

# %%
pooled =  nn.MaxPool1d(input)

# %%
input_start.view(n,c,w*h).permute(0,2,1).shape
# Out:
# torch.Size([1, 36, 6])

# %%
input[0].size()
# Out:
# torch.Size([6, 6, 6])

# %%
n, c, w, h = input.size()
input_updated = input.view(n,c,w*h).permute(0,2,1)
_, _, c = input_updated.size()
input_updated2 = input_updated.permute(0,2,1)
input_updated2.view(n,c,w,h)
# Out:
# tensor([[[[10.0000, 10.0000,  5.0000,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.4410,  0.0000,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  0.0000,  0.2562,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000]],
#
#          [[ 0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000],
#           [ 2.0132,  1.0354,  0.0000,  0.0000,  0.0000,  0.0000],
#           [ 0.3857,  0.0000,  0.1801,  0.0000,  0.0000,  0.0000],
#           [ 2.7994,  3.3148,  1.5957,  1.4995,  2.8311,  2.5134],
#           [ 0.0000,  1.3019,  1.5223,  0.3723,  1.8744,  1.4663],
#           [ 0.0000,  0.0000,  0.0000,  0.2828,  0.0000,  0.0000]],
#
#          [[ 0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000],
# ...

# %%
import numpy as np
test = np.array([[[[1,1],[3,1]],[[2,1],[1,1]]]])
np.max(test,axis=1).shape
# Out:
# (1, 2, 2)

# %% [markdown]
# # Task 2

# %%
input[0][0]
# Out:
# tensor([[10.0000, 10.0000,  5.0000,  0.0000,  0.0000,  0.0000],
#         [ 0.0000,  0.4410,  0.0000,  0.0000,  0.0000,  0.0000],
#         [ 0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000],
#         [ 0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000],
#         [ 0.0000,  0.0000,  0.0000,  0.0000,  0.2562,  0.0000],
#         [ 0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000]])

# %%
input = torch.tensor([
    [
        [   
            [1.000,  1.000,  1.000,    1.0000, 1.0000, 1.0000],
            [0.0000, 0.0000, 0.0000,   0.0000, 0.0000, 0.0000],
            [1.000,  1.000,  1.000,    1.0000, 1.0000, 1.0000],         
            [0.0000, 0.0000, 0.0000,   0.0000, 0.0000, 0.0000],
            [1.000,  1.000,  1.000,    1.0000, 1.0000, 1.0000],
            [0.0000, 0.0000, 0.0000,   0.0000, 0.0000, 0.0000],
        ],

        [
            [0.0000, 0.0000, 0.0000,   0.0000, 0.0000, 0.0000],
            [1.000,  1.000,  1.000,    1.0000, 1.0000, 1.0000],
            [0.0000, 0.0000, 0.0000,   0.0000, 0.0000, 0.0000],   
            [1.000,  1.000,  1.000,    1.0000, 1.0000, 1.0000],
            [0.0000, 0.0000, 0.0000,   0.0000, 0.0000, 0.0000],
            [1.000,  1.000,  1.000,    1.0000, 1.0000, 1.0000],
        ],

        [   
            [1.000,  1.000,  1.000,    1.0000, 1.0000, 1.0000],
            [0.0000, 0.0000, 0.0000,   0.0000, 0.0000, 0.0000],
            [1.000,  1.000,  1.000,    1.0000, 1.0000, 1.0000],         
            [0.0000, 0.0000, 0.0000,   0.0000, 0.0000, 0.0000],
            [1.000,  1.000,  1.000,    1.0000, 1.0000, 1.0000],
            [0.0000, 0.0000, 0.0000,   0.0000, 0.0000, 0.0000],
        ],

        [
            [0.0000, 0.0000, 0.0000,   0.0000, 0.0000, 0.0000],
            [1.000,  1.000,  1.000,    1.0000, 1.0000, 1.0000],
            [0.0000, 0.0000, 0.0000,   0.0000, 0.0000, 0.0000],   
            [1.000,  1.000,  1.000,    1.0000, 1.0000, 1.0000],
            [0.0000, 0.0000, 0.0000,   0.0000, 0.0000, 0.0000],
            [1.000,  1.000,  1.000,    1.0000, 1.0000, 1.0000],
        ],

        [   
            [1.000,  1.000,  1.000,    1.0000, 1.0000, 1.0000],
            [0.0000, 0.0000, 0.0000,   0.0000, 0.0000, 0.0000],
            [1.000,  1.000,  1.000,    1.0000, 1.0000, 1.0000],         
            [0.0000, 0.0000, 0.0000,   0.0000, 0.0000, 0.0000],
            [1.000,  1.000,  1.000,    1.0000, 1.0000, 1.0000],
            [0.0000, 0.0000, 0.0000,   0.0000, 0.0000, 0.0000],
        ],

        [
            [0.0000, 0.0000, 0.0000,   0.0000, 0.0000, 0.0000],
            [1.000,  1.000,  1.000,    1.0000, 1.0000, 1.0000],
            [0.0000, 0.0000, 0.0000,   0.0000, 0.0000, 0.0000],   
            [1.000,  1.000,  1.000,    1.0000, 1.0000, 1.0000],
            [0.0000, 0.0000, 0.0000,   0.0000, 0.0000, 0.0000],
            [1.000,  1.000,  1.000,    1.0000, 1.0000, 1.0000],
        ],
    ]
])

# %%
input.size()[1]
# Out:
# 6

# %%
input

# %%
output.size()
# Out:
# torch.Size([1, 6, 6, 6])

# %%
class ChannelPool(nn.MaxPool1d):   
    
    def forward(self, input):
        n, c, w, h = input.size()
        input = input.view(n,c,w*h).permute(0,2,1)
        # _, _, c = input.size()
        # input = input.permute(0,2,1)
        # return input.view(n,c,w,h)
        print(input.size())
        return input

# %%
#Get output tensor dimensions depending on compressions
compression = 2
n, c, w, h = input.size()
c = int(c/compression)
output = torch.empty(n, c, w, h)

index_pos = 0
#Compress input to output tensor
for index in range(0,input.size()[1],compression):
    output[0][index_pos] = torch.max(input[0][index],input[0][index+1])     
    index_pos +=1

# %%
output.size()
# Out:
# torch.Size([1, 3, 6, 6])

# %% [markdown]
# # Take 3

# %%
input = torch.tensor([[
    [
        [10000, 0.0000, 0.0000, 0.0000,  0.0000, 0.0000, 0.0000],
        [0.2760, 0.5899, 0.0000,  1.5647,  1.5647, 2.6089, 0.1658],
        [0.2375, 0.6943, 0.0000,  0.0000,  0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],

        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.2372,   0.0111,0.0111, 1.6338, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.4848, 0.0000]
    ],[
        [0.0000, 0.0000, 0.0000, 0.0000,  0.0000, 0.0000, 0.0000],
        [0.2760, 0.5899, 0.0000,  1.5647,  1.5647, 2.6089, 0.1658],
        [0.2375, 0.6943, 0.0000,  0.0000,  0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],

        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.2372,   0.0111,0.0111, 1.6338, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.4848, 0.0000]
    ],[
        [0.0000, 0.0000, 0.0000, 0.0000,  0.0000, 0.0000, 0.0000],
        [0.2760, 0.5899, 0.0000,  1.5647,  1.5647, 2.6089, 0.1658],
        [0.2375, 0.6943, 0.0000,  0.0000,  0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],

        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.2372,   0.0111,0.0111, 1.6338, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.4848, 0.0000]
    ],[
        [0.0000, 0.0000, 0.0000, 0.0000,  0.0000, 0.0000, 0.0000],
        [0.2760, 0.5899, 0.0000,  1.5647,  1.5647, 2.6089, 0.1658],
        [0.2375, 0.6943, 0.0000,  0.0000,  0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],

        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.2372,   0.0111,0.0111, 1.6338, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.4848, 0.0000]
    ],[
        [0.0000, 0.0000, 0.0000, 0.0000,  0.0000, 0.0000, 0.0000],
        [0.2760, 0.5899, 0.0000,  1.5647,  1.5647, 2.6089, 0.1658],
        [0.2375, 0.6943, 0.0000,  0.0000,  0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],

        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.2372,   0.0111,0.0111, 1.6338, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.4848, 0.0000]
    ],[
        [0.0000, 0.0000, 0.0000, 0.0000,  0.0000, 0.0000, 0.0000],
        [0.2760, 0.5899, 0.0000,  1.5647,  1.5647, 2.6089, 0.1658],
        [0.2375, 0.6943, 0.0000,  0.0000,  0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],

        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.2372,   0.0111,0.0111, 1.6338, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.4848, 0.0000]
    ],[
        [0.0000, 0.0000, 0.0000, 0.0000,  0.0000, 0.0000, 0.0000],
        [0.2760, 0.5899, 0.0000,  1.5647,  1.5647, 2.6089, 0.1658],
        [0.2375, 0.6943, 0.0000,  0.0000,  0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],

        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.2372,   0.0111,0.0111, 1.6338, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.4848, 0.0000]
    ],[
        [0.0000, 0.0000, 0.0000, 0.0000,  0.0000, 0.0000, 0.0000],
        [0.2760, 0.5899, 0.0000,  1.5647,  1.5647, 2.6089, 0.1658],
        [0.2375, 0.6943, 0.0000,  0.0000,  0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],

        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.2372,   0.0111,0.0111, 1.6338, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.4848, 0.0000]
    ],[
        [0.0000, 0.0000, 0.0000, 0.0000,  0.0000, 0.0000, 0.0000],
        [0.2760, 0.5899, 0.0000,  1.5647,  1.5647, 2.6089, 0.1658],
        [0.2375, 0.6943, 0.0000,  0.0000,  0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],

        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.2372,   0.0111,0.0111, 1.6338, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.4848, 0.0000]
    ],[
        [0.0000, 0.0000, 0.0000, 0.0000,  0.0000, 0.0000, 0.0000],
        [0.2760, 0.5899, 0.0000,  1.5647,  1.5647, 2.6089, 0.1658],
        [0.2375, 0.6943, 0.0000,  0.0000,  0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],

        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.2372,   0.0111,0.0111, 1.6338, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.4848, 0.0000]
    ],[
        [0.0000, 0.0000, 0.0000, 0.0000,  0.0000, 0.0000, 0.0000],
        [0.2760, 0.5899, 0.0000,  1.5647,  1.5647, 2.6089, 0.1658],
        [0.2375, 0.6943, 0.0000,  0.0000,  0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],

        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.2372,   0.0111,0.0111, 1.6338, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.4848, 0.0000]
    ],[
        [0.0000, 0.0000, 0.0000, 0.0000,  0.0000, 0.0000, 0.0000],
        [0.2760, 0.5899, 0.0000,  1.5647,  1.5647, 2.6089, 0.1658],
        [0.2375, 0.6943, 0.0000,  0.0000,  0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],

        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.2372,   0.0111,0.0111, 1.6338, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.4848, 0.0000]
    ],[
        [0.0000, 0.0000, 0.0000, 0.0000,  0.0000, 0.0000, 0.0000],
        [0.2760, 0.5899, 0.0000,  1.5647,  1.5647, 2.6089, 0.1658],
        [0.2375, 0.6943, 0.0000,  0.0000,  0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],

        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.2372,   0.0111,0.0111, 1.6338, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.4848, 0.0000]
    ],[
        [0.0000, 0.0000, 0.0000, 0.0000,  0.0000, 0.0000, 0.0000],
        [0.2760, 0.5899, 0.0000,  1.5647,  1.5647, 2.6089, 0.1658],
        [0.2375, 0.6943, 0.0000,  0.0000,  0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],

        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.2372,   0.0111,0.0111, 1.6338, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.4848, 0.0000]
    ],[
        [0.0000, 0.0000, 0.0000, 0.0000,  0.0000, 0.0000, 0.0000],
        [0.2760, 0.5899, 0.0000,  1.5647,  1.5647, 2.6089, 0.1658],
        [0.2375, 0.6943, 0.0000,  0.0000,  0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],

        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.2372,   0.0111,0.0111, 1.6338, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.4848, 0.0000]
    ],[
        [0.0000, 0.0000, 0.0000, 0.0000,  0.0000, 0.0000, 0.0000],
        [0.2760, 0.5899, 0.0000,  1.5647,  1.5647, 2.6089, 0.1658],
        [0.2375, 0.6943, 0.0000,  0.0000,  0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],

        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.2372,   0.0111,0.0111, 1.6338, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.4848, 0.0000]
    ],[
        [0.0000, 0.0000, 0.0000, 0.0000,  0.0000, 0.0000, 0.0000],
        [0.2760, 0.5899, 0.0000,  1.5647,  1.5647, 2.6089, 0.1658],
        [0.2375, 0.6943, 0.0000,  0.0000,  0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],

        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.2372,   0.0111,0.0111, 1.6338, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.4848, 0.0000]
    ],[
        [0.0000, 0.0000, 0.0000, 0.0000,  0.0000, 0.0000, 0.0000],
        [0.2760, 0.5899, 0.0000,  1.5647,  1.5647, 2.6089, 0.1658],
        [0.2375, 0.6943, 0.0000,  0.0000,  0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],

        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.2372,   0.0111,0.0111, 1.6338, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.4848, 0.0000]
    ],[
        [0.0000, 0.0000, 0.0000, 0.0000,  0.0000, 0.0000, 0.0000],
        [0.2760, 0.5899, 0.0000,  1.5647,  1.5647, 2.6089, 0.1658],
        [0.2375, 0.6943, 0.0000,  0.0000,  0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],

        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.2372,   0.0111,0.0111, 1.6338, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.4848, 0.0000]
    ],[
        [0.0000, 0.0000, 0.0000, 0.0000,  0.0000, 0.0000, 0.0000],
        [0.2760, 0.5899, 0.0000,  1.5647,  1.5647, 2.6089, 0.1658],
        [0.2375, 0.6943, 0.0000,  0.0000,  0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],

        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.2372,   0.0111,0.0111, 1.6338, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.4848, 0.0000]
    ],[
        [0.0000, 0.0000, 0.0000, 0.0000,  0.0000, 0.0000, 0.0000],
        [0.2760, 0.5899, 0.0000,  1.5647,  1.5647, 2.6089, 0.1658],
        [0.2375, 0.6943, 0.0000,  0.0000,  0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],

        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.2372,   0.0111,0.0111, 1.6338, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.4848, 0.0000]
    ],[
        [0.0000, 0.0000, 0.0000, 0.0000,  0.0000, 0.0000, 0.0000],
        [0.2760, 0.5899, 0.0000,  1.5647,  1.5647, 2.6089, 0.1658],
        [0.2375, 0.6943, 0.0000,  0.0000,  0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],

        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.2372,   0.0111,0.0111, 1.6338, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.4848, 0.0000]
    ],[
        [0.0000, 0.0000, 0.0000, 0.0000,  0.0000, 0.0000, 0.0000],
        [0.2760, 0.5899, 0.0000,  1.5647,  1.5647, 2.6089, 0.1658],
        [0.2375, 0.6943, 0.0000,  0.0000,  0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],

        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.2372,   0.0111,0.0111, 1.6338, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.4848, 0.0000]
    ],[
        [0.0000, 0.0000, 0.0000, 0.0000,  0.0000, 0.0000, 0.0000],
        [0.2760, 0.5899, 0.0000,  1.5647,  1.5647, 2.6089, 0.1658],
        [0.2375, 0.6943, 0.0000,  0.0000,  0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],

        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.2372,   0.0111,0.0111, 1.6338, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.4848, 0.0000]
    ],[
        [0.0000, 0.0000, 0.0000, 0.0000,  0.0000, 0.0000, 0.0000],
        [0.2760, 0.5899, 0.0000,  1.5647,  1.5647, 2.6089, 0.1658],
        [0.2375, 0.6943, 0.0000,  0.0000,  0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],

        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.2372,   0.0111,0.0111, 1.6338, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.4848, 0.0000]
    ],[
        [0.0000, 0.0000, 0.0000, 0.0000,  0.0000, 0.0000, 0.0000],
        [0.2760, 0.5899, 0.0000,  1.5647,  1.5647, 2.6089, 0.1658],
        [0.2375, 0.6943, 0.0000,  0.0000,  0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],

        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.2372,   0.0111,0.0111, 1.6338, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.4848, 0.0000]
    ],[
        [0.0000, 0.0000, 0.0000, 0.0000,  0.0000, 0.0000, 0.0000],
        [0.2760, 0.5899, 0.0000,  1.5647,  1.5647, 2.6089, 0.1658],
        [0.2375, 0.6943, 0.0000,  0.0000,  0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],

        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.2372,   0.0111,0.0111, 1.6338, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.4848, 0.0000]
    ],[
        [0.0000, 0.0000, 0.0000, 0.0000,  0.0000, 0.0000, 0.0000],
        [0.2760, 0.5899, 0.0000,  1.5647,  1.5647, 2.6089, 0.1658],
        [0.2375, 0.6943, 0.0000,  0.0000,  0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],

        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.2372,   0.0111,0.0111, 1.6338, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.4848, 0.0000]
    ],[
        [0.0000, 0.0000, 0.0000, 0.0000,  0.0000, 0.0000, 0.0000],
        [0.2760, 0.5899, 0.0000,  1.5647,  1.5647, 2.6089, 0.1658],
        [0.2375, 0.6943, 0.0000,  0.0000,  0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],

        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.2372,   0.0111,0.0111, 1.6338, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.4848, 0.0000]
    ],[
        [0.0000, 0.0000, 0.0000, 0.0000,  0.0000, 0.0000, 0.0000],
        [0.2760, 0.5899, 0.0000,  1.5647,  1.5647, 2.6089, 0.1658],
        [0.2375, 0.6943, 0.0000,  0.0000,  0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],

        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.2372,   0.0111,0.0111, 1.6338, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.4848, 0.0000]
    ],[
        [0.0000, 0.0000, 0.0000, 0.0000,  0.0000, 0.0000, 0.0000],
        [0.2760, 0.5899, 0.0000,  1.5647,  1.5647, 2.6089, 0.1658],
        [0.2375, 0.6943, 0.0000,  0.0000,  0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],

        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.2372,   0.0111,0.0111, 1.6338, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.4848, 0.0000]
    ],[
        [0.0000, 0.0000, 0.0000, 0.0000,  0.0000, 0.0000, 0.0000],
        [0.2760, 0.5899, 0.0000,  1.5647,  1.5647, 2.6089, 0.1658],
        [0.2375, 0.6943, 0.0000,  0.0000,  0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],

        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.2372,   0.0111,0.0111, 1.6338, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.4848, 0.0000]
    ],[
        [0.0000, 0.0000, 0.0000, 0.0000,  0.0000, 0.0000, 0.0000],
        [0.2760, 0.5899, 0.0000,  1.5647,  1.5647, 2.6089, 0.1658],
        [0.2375, 0.6943, 0.0000,  0.0000,  0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],

        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.2372,   0.0111,0.0111, 1.6338, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.4848, 0.0000]
    ],[
        [0.0000, 0.0000, 0.0000, 0.0000,  0.0000, 0.0000, 0.0000],
        [0.2760, 0.5899, 0.0000,  1.5647,  1.5647, 2.6089, 0.1658],
        [0.2375, 0.6943, 0.0000,  0.0000,  0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],

        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.2372,   0.0111,0.0111, 1.6338, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.4848, 0.0000]
    ],[
        [0.0000, 0.0000, 0.0000, 0.0000,  0.0000, 0.0000, 0.0000],
        [0.2760, 0.5899, 0.0000,  1.5647,  1.5647, 2.6089, 0.1658],
        [0.2375, 0.6943, 0.0000,  0.0000,  0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],

        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.2372,   0.0111,0.0111, 1.6338, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.4848, 0.0000]
    ],[
        [0.0000, 0.0000, 0.0000, 0.0000,  0.0000, 0.0000, 0.0000],
        [0.2760, 0.5899, 0.0000,  1.5647,  1.5647, 2.6089, 0.1658],
        [0.2375, 0.6943, 0.0000,  0.0000,  0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],

        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.2372,   0.0111,0.0111, 1.6338, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.4848, 0.0000]
    ],[
        [0.0000, 0.0000, 0.0000, 0.0000,  0.0000, 0.0000, 0.0000],
        [0.2760, 0.5899, 0.0000,  1.5647,  1.5647, 2.6089, 0.1658],
        [0.2375, 0.6943, 0.0000,  0.0000,  0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],

        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.2372,   0.0111,0.0111, 1.6338, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.4848, 0.0000]
    ],[
        [0.0000, 0.0000, 0.0000, 0.0000,  0.0000, 0.0000, 0.0000],
        [0.2760, 0.5899, 0.0000,  1.5647,  1.5647, 2.6089, 0.1658],
        [0.2375, 0.6943, 0.0000,  0.0000,  0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],

        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.2372,   0.0111,0.0111, 1.6338, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.4848, 0.0000]
    ],[
        [0.0000, 0.0000, 0.0000, 0.0000,  0.0000, 0.0000, 0.0000],
        [0.2760, 0.5899, 0.0000,  1.5647,  1.5647, 2.6089, 0.1658],
        [0.2375, 0.6943, 0.0000,  0.0000,  0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],

        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.2372,   0.0111,0.0111, 1.6338, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.4848, 0.0000]
    ],[
        [0.0000, 0.0000, 0.0000, 0.0000,  0.0000, 0.0000, 0.0000],
        [0.2760, 0.5899, 0.0000,  1.5647,  1.5647, 2.6089, 0.1658],
        [0.2375, 0.6943, 0.0000,  0.0000,  0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],

        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.2372,   0.0111,0.0111, 1.6338, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.4848, 0.0000]
    ],[
        [0.0000, 0.0000, 0.0000, 0.0000,  0.0000, 0.0000, 0.0000],
        [0.2760, 0.5899, 0.0000,  1.5647,  1.5647, 2.6089, 0.1658],
        [0.2375, 0.6943, 0.0000,  0.0000,  0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],

        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.2372,   0.0111,0.0111, 1.6338, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.4848, 0.0000]
    ],[
        [0.0000, 0.0000, 0.0000, 0.0000,  0.0000, 0.0000, 0.0000],
        [0.2760, 0.5899, 0.0000,  1.5647,  1.5647, 2.6089, 0.1658],
        [0.2375, 0.6943, 0.0000,  0.0000,  0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],

        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.2372,   0.0111,0.0111, 1.6338, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.4848, 0.0000]
    ],[
        [0.0000, 0.0000, 0.0000, 0.0000,  0.0000, 0.0000, 0.0000],
        [0.2760, 0.5899, 0.0000,  1.5647,  1.5647, 2.6089, 0.1658],
        [0.2375, 0.6943, 0.0000,  0.0000,  0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],

        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.2372,   0.0111,0.0111, 1.6338, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.4848, 0.0000]
    ],[
        [0.0000, 0.0000, 0.0000, 0.0000,  0.0000, 0.0000, 0.0000],
        [0.2760, 0.5899, 0.0000,  1.5647,  1.5647, 2.6089, 0.1658],
        [0.2375, 0.6943, 0.0000,  0.0000,  0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],

        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.2372,   0.0111,0.0111, 1.6338, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.4848, 0.0000]
    ],[
        [0.0000, 0.0000, 0.0000, 0.0000,  0.0000, 0.0000, 0.0000],
        [0.2760, 0.5899, 0.0000,  1.5647,  1.5647, 2.6089, 0.1658],
        [0.2375, 0.6943, 0.0000,  0.0000,  0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],

        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.2372,   0.0111,0.0111, 1.6338, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.4848, 0.0000]
    ],[
        [0.0000, 0.0000, 0.0000, 0.0000,  0.0000, 0.0000, 0.0000],
        [0.2760, 0.5899, 0.0000,  1.5647,  1.5647, 2.6089, 0.1658],
        [0.2375, 0.6943, 0.0000,  0.0000,  0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],

        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.2372,   0.0111,0.0111, 1.6338, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.4848, 0.0000]
    ],[
        [0.0000, 0.0000, 0.0000, 0.0000,  0.0000, 0.0000, 0.0000],
        [0.2760, 0.5899, 0.0000,  1.5647,  1.5647, 2.6089, 0.1658],
        [0.2375, 0.6943, 0.0000,  0.0000,  0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],

        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.2372,   0.0111,0.0111, 1.6338, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.4848, 0.0000]
    ],[
        [0.0000, 0.0000, 0.0000, 0.0000,  0.0000, 0.0000, 0.0000],
        [0.2760, 0.5899, 0.0000,  1.5647,  1.5647, 2.6089, 0.1658],
        [0.2375, 0.6943, 0.0000,  0.0000,  0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],

        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.2372,   0.0111,0.0111, 1.6338, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.4848, 0.0000]
    ],[
        [0.0000, 0.0000, 0.0000, 0.0000,  0.0000, 0.0000, 0.0000],
        [0.2760, 0.5899, 0.0000,  1.5647,  1.5647, 2.6089, 0.1658],
        [0.2375, 0.6943, 0.0000,  0.0000,  0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],

        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.2372,   0.0111,0.0111, 1.6338, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.4848, 0.0000]
    ],[
        [0.0000, 0.0000, 0.0000, 0.0000,  0.0000, 0.0000, 0.0000],
        [0.2760, 0.5899, 0.0000,  1.5647,  1.5647, 2.6089, 0.1658],
        [0.2375, 0.6943, 0.0000,  0.0000,  0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],

        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.2372,   0.0111,0.0111, 1.6338, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.4848, 0.0000]
    ],[
        [0.0000, 0.0000, 0.0000, 0.0000,  0.0000, 0.0000, 0.0000],
        [0.2760, 0.5899, 0.0000,  1.5647,  1.5647, 2.6089, 0.1658],
        [0.2375, 0.6943, 0.0000,  0.0000,  0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],

        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.2372,   0.0111,0.0111, 1.6338, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.4848, 0.0000]
    ],[
        [0.0000, 0.0000, 0.0000, 0.0000,  0.0000, 0.0000, 0.0000],
        [0.2760, 0.5899, 0.0000,  1.5647,  1.5647, 2.6089, 0.1658],
        [0.2375, 0.6943, 0.0000,  0.0000,  0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],

        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.2372,   0.0111,0.0111, 1.6338, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.4848, 0.0000]
    ],[
        [0.0000, 0.0000, 0.0000, 0.0000,  0.0000, 0.0000, 0.0000],
        [0.2760, 0.5899, 0.0000,  1.5647,  1.5647, 2.6089, 0.1658],
        [0.2375, 0.6943, 0.0000,  0.0000,  0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],

        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.2372,   0.0111,0.0111, 1.6338, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.4848, 0.0000]
    ],[
        [0.0000, 0.0000, 0.0000, 0.0000,  0.0000, 0.0000, 0.0000],
        [0.2760, 0.5899, 0.0000,  1.5647,  1.5647, 2.6089, 0.1658],
        [0.2375, 0.6943, 0.0000,  0.0000,  0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],

        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.2372,   0.0111,0.0111, 1.6338, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.4848, 0.0000]
    ],[
        [0.0000, 0.0000, 0.0000, 0.0000,  0.0000, 0.0000, 0.0000],
        [0.2760, 0.5899, 0.0000,  1.5647,  1.5647, 2.6089, 0.1658],
        [0.2375, 0.6943, 0.0000,  0.0000,  0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],

        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.2372,   0.0111,0.0111, 1.6338, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.4848, 0.0000]
    ],[
        [0.0000, 0.0000, 0.0000, 0.0000,  0.0000, 0.0000, 0.0000],
        [0.2760, 0.5899, 0.0000,  1.5647,  1.5647, 2.6089, 0.1658],
        [0.2375, 0.6943, 0.0000,  0.0000,  0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],

        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.2372,   0.0111,0.0111, 1.6338, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.4848, 0.0000]
    ],[
        [0.0000, 0.0000, 0.0000, 0.0000,  0.0000, 0.0000, 0.0000],
        [0.2760, 0.5899, 0.0000,  1.5647,  1.5647, 2.6089, 0.1658],
        [0.2375, 0.6943, 0.0000,  0.0000,  0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],

        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.2372,   0.0111,0.0111, 1.6338, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.4848, 0.0000]
    ],[
        [0.0000, 0.0000, 0.0000, 0.0000,  0.0000, 0.0000, 0.0000],
        [0.2760, 0.5899, 0.0000,  1.5647,  1.5647, 2.6089, 0.1658],
        [0.2375, 0.6943, 0.0000,  0.0000,  0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],

        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.2372,   0.0111,0.0111, 1.6338, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.4848, 0.0000]
    ],[
        [0.0000, 0.0000, 0.0000, 0.0000,  0.0000, 0.0000, 0.0000],
        [0.2760, 0.5899, 0.0000,  1.5647,  1.5647, 2.6089, 0.1658],
        [0.2375, 0.6943, 0.0000,  0.0000,  0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],

        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.2372,   0.0111,0.0111, 1.6338, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.4848, 0.0000]
    ],[
        [0.0000, 0.0000, 0.0000, 0.0000,  0.0000, 0.0000, 0.0000],
        [0.2760, 0.5899, 0.0000,  1.5647,  1.5647, 2.6089, 0.1658],
        [0.2375, 0.6943, 0.0000,  0.0000,  0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],

        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.2372,   0.0111,0.0111, 1.6338, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.4848, 0.0000]
    ],[
        [0.0000, 0.0000, 0.0000, 0.0000,  0.0000, 0.0000, 0.0000],
        [0.2760, 0.5899, 0.0000,  1.5647,  1.5647, 2.6089, 0.1658],
        [0.2375, 0.6943, 0.0000,  0.0000,  0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],

        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.2372,   0.0111,0.0111, 1.6338, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.4848, 0.0000]
    ],[
        [0.0000, 0.0000, 0.0000, 0.0000,  0.0000, 0.0000, 0.0000],
        [0.2760, 0.5899, 0.0000,  1.5647,  1.5647, 2.6089, 0.1658],
        [0.2375, 0.6943, 0.0000,  0.0000,  0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],

        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.2372,   0.0111,0.0111, 1.6338, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.4848, 0.0000]
    ],[
        [0.0000, 0.0000, 0.0000, 0.0000,  0.0000, 0.0000, 0.0000],
        [0.2760, 0.5899, 0.0000,  1.5647,  1.5647, 2.6089, 0.1658],
        [0.2375, 0.6943, 0.0000,  0.0000,  0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],

        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.2372,   0.0111,0.0111, 1.6338, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.4848, 0.0000]
    ],[
        [0.0000, 0.0000, 0.0000, 0.0000,  0.0000, 0.0000, 0.0000],
        [0.2760, 0.5899, 0.0000,  1.5647,  1.5647, 2.6089, 0.1658],
        [0.2375, 0.6943, 0.0000,  0.0000,  0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],

        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.0000, 0.0000],
        [0.0000, 0.0000, 0.2372,   0.0111,0.0111, 1.6338, 0.0000],
        [0.0000, 0.0000, 0.0000,   0.0000,0.0000, 0.4848, 0.0000]
    ],

]])

# %%
input.size()
# Out:
# torch.Size([1, 64, 7, 7])

# %%
out, inds = torch.max(input,dim=1,keepdim=True)
out.shape
# Out:
# torch.Size([1, 1, 7, 7])

# %%
def foward(input):
    kernal_size = 7
    stride = 2
    padding = 3
    compression = 2 #Hard coded but can be calcualted
    #Get output tensor dimensions depending on compressions

    n, c, w, h = input.size()
    c = int(c/compression)
    # output = torch.empty(n, c, w, h).cuda()
    output = torch.ones(n, c, w, h)


    #Add padding to input so work with kernal size
    input = torch.nn.functional.pad(input, (0, 0, 0, 0, padding, padding), "constant", 0)

    index_pos = 0
    count = 1
    #Compress input to output tensor
    for index in range(0,input.size()[1]-kernal_size,stride):
        output[0][index_pos] = torch.max(input[0][index:index+kernal_size-1],axis=0).values
        index_pos +=1
    return output

output0 = foward(input)

# %%
#This is quicker
torch.max(input[0][0:6],axis=0).values
# Out:
# tensor([[1.0000e+04, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#          0.0000e+00],
#         [2.7600e-01, 5.8990e-01, 0.0000e+00, 1.5647e+00, 1.5647e+00, 2.6089e+00,
#          1.6580e-01],
#         [2.3750e-01, 6.9430e-01, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#          0.0000e+00],
#         [0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#          0.0000e+00],
#         [0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#          0.0000e+00],
#         [0.0000e+00, 0.0000e+00, 2.3720e-01, 1.1100e-02, 1.1100e-02, 1.6338e+00,
#          0.0000e+00],
#         [0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 4.8480e-01,
#          0.0000e+00]])

# %%
class ChannelPool(nn.Module):

    def __init__(self, kernel_size=7, stride=None, padding=0, dilation=1,
                 return_indices=False, ceil_mode=False):
        super().__init__()
        self.kernel_size = kernel_size
        self.stride = stride or kernel_size
        self.padding = padding
        self.dilation = dilation
        self.return_indices = return_indices
        self.ceil_mode = ceil_mode
        self.compression = 2
        self.output = None


    def forward(self, input):
        start_time = time.time()
        #Add padding to input so work with kernal size
        input = torch.nn.functional.pad(input, (0, 0, 0, 0, self.padding, self.padding), "constant", 0)
        
        #Get output
        output = torch.empty(1,256,7,7)
        output[0] = torch.stack([torch.max(input[0][index:index+self.kernel_size-1],axis=0)[0]
                  for index in range(0,input.size()[1]-self.kernel_size,self.stride)])
        print(time.time()-start_time)
        return output
    
test = ChannelPool(kernel_size=7, stride=2, padding=3, dilation=1, ceil_mode=False)
test.forward(input).size()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-302-7be18e3060ff> in <module>
#      27
#      28 test = ChannelPool(kernel_size=7, stride=2, padding=3, dilation=1, ceil_mode=False)
# ---> 29 test.forward(input).size()
#
# <ipython-input-302-7be18e3060ff> in forward(self, input)
#      22         output = torch.empty(1,256,7,7)
#      23         output[0] = torch.stack([torch.max(input[0][index:index+self.kernel_size-1],axis=0)[0]
# ---> 24                   for index in range(0,input.size()[1]-self.kernel_size,self.stride)])
#      25         print(time.time()-start_time)
#      26         return output
#
# RuntimeError: The expanded size of the tensor (256) must match the existing size (32) at non-singleton dimension 0.  Target sizes: [256, 7, 7].  Tensor sizes: [32, 7, 7]
