# %%
import torch
import torch.nn as nn

# %%
input = torch.tensor([[[[10, 10.0000, 5,   0.0000, 0.0000, 0.0000],
          [0.0000, 0.4410, 0.0000,   0.0000, 0.0000, 0.0000],
          [0.0000, 0.0000, 0.0000,   0.0000, 0.0000, 0.0000],
          
          [0.0000, 0.0000, 0.0000,   0.0000, 0.0000, 0.0000],
          [0.0000, 0.0000, 0.0000,   0.0000, 0.2562, 0.0000],
          [0.0000, 0.0000, 0.0000,   0.0000, 0.0000, 0.0000]],

         [[0.0000, 0.0000, 0.0000,   0.0000, 0.0000, 0.0000],
          [2.0132, 1.0354, 0.0000,   0.0000, 0.0000, 0.0000],
          [0.3857, 0.0000, 0.1801,   0.0000, 0.0000, 0.0000],
          
          [2.7994, 3.3148, 1.5957,   1.4995, 2.8311, 2.5134],
          [0.0000, 1.3019, 1.5223,   0.3723, 1.8744, 1.4663],
          [0.0000, 0.0000, 0.0000,   0.2828, 0.0000, 0.0000]],

         [[0.0000, 0.0000, 0.0000,   0.0000, 0.0000, 0.0000],
          [0.0000, 0.0000, 0.0000,   0.0000, 0.0000, 0.0000],
          [0.0000, 0.0000, 0.0000,   0.0000, 0.0000, 0.0000],
          
          [0.0000, 0.0000, 0.0000,   0.0000, 0.0000, 0.0000],
          [0.6144, 0.3670, 0.0000,   0.0000, 0.0000, 0.0000],
          [0.0000, 0.0000, 0.0000,   0.0000, 0.0000, 0.0000]],

         

         [[0.0000, 0.0000, 6.0000,   6, 0.0000, 0.0000],
          [0.0000, 2.2975, 0.0000,   0.0000, 0.0000, 0.2153],
          [0.0000, 1.8645, 0.0000,   0.0000, 0.0000, 0.0000],
          
          [1.3304, 0.6114, 0.7940,   0.0000, 0.0000, 0.0000],
          [5.8138, 3.8091, 0.6860,   0.0000, 0.0000, 0.0000],
          [0.0000, 0.0000, 0.0000,   0.7999, 0.0000, 0.0000]],

         [[0.0000, 0.0000, 0.0000,   0.0000, 0.0000, 0.0000],
          [0.0000, 0.0000, 0.0000,   0.0000, 0.0000, 0.0000],
          [0.0000, 0.0000, 0.0000,   0.0000, 0.0000, 0.0000],
          
          [0.0000, 0.0000, 0.0290,   0.0000, 0.0000, 0.0000],
          [0.0000, 0.0000, 0.0000,   0.0000, 0.0000, 0.0000],
          [0.0000, 0.0000, 0.0000,   0.0000, 0.1629, 0.9383]],

         [[0.0000, 0.0000, 0.0000,   0.0000, 0.0000, 0.0000],
          [0.0000, 0.0000, 0.0000,   0.0000, 0.0000, 0.0000],
          [0.0000, 0.0000, 0.0000,   0.0000, 0.0000, 0.0000],
          
          [0.0000, 0.0000, 0.0000,   0.0000, 0.0000, 0.0000],
          [0.2174, 0.9764, 0.0000,   0.0000, 0.0000, 0.0000],
          [0.0000, 0.2185, 0.2086,   0.0000, 0.0000, 0.0000]]]])

# %%
input_start.size()
# Out:
# torch.Size([1, 6, 6, 6])

# %%
n, c, w, h = input.size()

# %%
input2 = input.view(n,c,w*h).permute(0,2,1)

# %%
pooled =  nn.MaxPool1d(input)

# %%
input_start.view(n,c,w*h).permute(0,2,1).shape
# Out:
# torch.Size([1, 36, 6])

# %%
input[0].size()
# Out:
# torch.Size([6, 6, 6])

# %%
n, c, w, h = input.size()
input_updated = input.view(n,c,w*h).permute(0,2,1)
_, _, c = input_updated.size()
input_updated2 = input_updated.permute(0,2,1)
input_updated2.view(n,c,w,h)
# Out:
# tensor([[[[10.0000, 10.0000,  5.0000,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.4410,  0.0000,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  0.0000,  0.2562,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000]],
#
#          [[ 0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000],
#           [ 2.0132,  1.0354,  0.0000,  0.0000,  0.0000,  0.0000],
#           [ 0.3857,  0.0000,  0.1801,  0.0000,  0.0000,  0.0000],
#           [ 2.7994,  3.3148,  1.5957,  1.4995,  2.8311,  2.5134],
#           [ 0.0000,  1.3019,  1.5223,  0.3723,  1.8744,  1.4663],
#           [ 0.0000,  0.0000,  0.0000,  0.2828,  0.0000,  0.0000]],
#
#          [[ 0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000],
# ...

# %%
import numpy as np
test = np.array([[[[1,1],[3,1]],[[2,1],[1,1]]]])
np.max(test,axis=1).shape
# Out:
# (1, 2, 2)

# %% [markdown]
# # Task 2

# %%
input[0][0]
# Out:
# tensor([[10.0000, 10.0000,  5.0000,  0.0000,  0.0000,  0.0000],
#         [ 0.0000,  0.4410,  0.0000,  0.0000,  0.0000,  0.0000],
#         [ 0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000],
#         [ 0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000],
#         [ 0.0000,  0.0000,  0.0000,  0.0000,  0.2562,  0.0000],
#         [ 0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000]])

# %%
input = torch.tensor([
    [
        [   
            [1.000,  1.000,  1.000,    1.0000, 1.0000, 1.0000],
            [0.0000, 0.0000, 0.0000,   0.0000, 0.0000, 0.0000],
            [1.000,  1.000,  1.000,    1.0000, 1.0000, 1.0000],         
            [0.0000, 0.0000, 0.0000,   0.0000, 0.0000, 0.0000],
            [1.000,  1.000,  1.000,    1.0000, 1.0000, 1.0000],
            [0.0000, 0.0000, 0.0000,   0.0000, 0.0000, 0.0000],
        ],

        [
            [0.0000, 0.0000, 0.0000,   0.0000, 0.0000, 0.0000],
            [1.000,  1.000,  1.000,    1.0000, 1.0000, 1.0000],
            [0.0000, 0.0000, 0.0000,   0.0000, 0.0000, 0.0000],   
            [1.000,  1.000,  1.000,    1.0000, 1.0000, 1.0000],
            [0.0000, 0.0000, 0.0000,   0.0000, 0.0000, 0.0000],
            [1.000,  1.000,  1.000,    1.0000, 1.0000, 1.0000],
        ],

        [   
            [1.000,  1.000,  1.000,    1.0000, 1.0000, 1.0000],
            [0.0000, 0.0000, 0.0000,   0.0000, 0.0000, 0.0000],
            [1.000,  1.000,  1.000,    1.0000, 1.0000, 1.0000],         
            [0.0000, 0.0000, 0.0000,   0.0000, 0.0000, 0.0000],
            [1.000,  1.000,  1.000,    1.0000, 1.0000, 1.0000],
            [0.0000, 0.0000, 0.0000,   0.0000, 0.0000, 0.0000],
        ],

        [
            [0.0000, 0.0000, 0.0000,   0.0000, 0.0000, 0.0000],
            [1.000,  1.000,  1.000,    1.0000, 1.0000, 1.0000],
            [0.0000, 0.0000, 0.0000,   0.0000, 0.0000, 0.0000],   
            [1.000,  1.000,  1.000,    1.0000, 1.0000, 1.0000],
            [0.0000, 0.0000, 0.0000,   0.0000, 0.0000, 0.0000],
            [1.000,  1.000,  1.000,    1.0000, 1.0000, 1.0000],
        ],

        [   
            [1.000,  1.000,  1.000,    1.0000, 1.0000, 1.0000],
            [0.0000, 0.0000, 0.0000,   0.0000, 0.0000, 0.0000],
            [1.000,  1.000,  1.000,    1.0000, 1.0000, 1.0000],         
            [0.0000, 0.0000, 0.0000,   0.0000, 0.0000, 0.0000],
            [1.000,  1.000,  1.000,    1.0000, 1.0000, 1.0000],
            [0.0000, 0.0000, 0.0000,   0.0000, 0.0000, 0.0000],
        ],

        [
            [0.0000, 0.0000, 0.0000,   0.0000, 0.0000, 0.0000],
            [1.000,  1.000,  1.000,    1.0000, 1.0000, 1.0000],
            [0.0000, 0.0000, 0.0000,   0.0000, 0.0000, 0.0000],   
            [1.000,  1.000,  1.000,    1.0000, 1.0000, 1.0000],
            [0.0000, 0.0000, 0.0000,   0.0000, 0.0000, 0.0000],
            [1.000,  1.000,  1.000,    1.0000, 1.0000, 1.0000],
        ],
    ]
])

# %%
input.size()[1]
# Out:
# 6

# %%
input

# %%
output.size()
# Out:
# torch.Size([1, 6, 6, 6])

# %%
class ChannelPool(nn.MaxPool1d):
    
    
    def forward(self, input):
        n, c, w, h = input.size()
        input = input.view(n,c,w*h).permute(0,2,1)
        # _, _, c = input.size()
        # input = input.permute(0,2,1)
        # return input.view(n,c,w,h)
        print(input.size())
        return input

# %%
#Get output tensor dimensions depending on compressions
compression = 2
n, c, w, h = input.size()
c = int(c/compression)
output = torch.empty(n, c, w, h)

index_pos = 0
#Compress input to output tensor
for index in range(0,input.size()[1],compression):
    output[0][index_pos] = torch.max(input[0][index],input[0][index+1])     
    index_pos +=1

# %%
output.size()
# Out:
# torch.Size([1, 3, 6, 6])
