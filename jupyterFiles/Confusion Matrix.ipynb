# %%
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import torch
import os
import glob

# %%
[file for file in glob.glob("../saves/confusionMatrix/310*")]
# Out:
# ['../saves/confusionMatrix/310_CM_20200316-142554.xlsx']

# %%
def get_cm(model_id,sheet_name,version=0):
    sheet_names = ['total','make','model','submodel','generation']
    print("getting", sheet_names[sheet_name]," confusion matrix")
    cm_path = '../saves/confusionMatrix/'
    filepaths = [file for file in glob.glob(os.path.join(cm_path,str(model_id) + '_CM*'))]
    return pd.read_excel(filepaths[version],sheet_name=sheet_names[0])

# %%
plt.figure(figsize=(20,20))
df_cm = get_cm(310,3)
sn.set(font_scale=1.4) # for label size
sn.heatmap(df_cm, annot=True, annot_kws={"size": 5}) # font size

plt.show()
# Out:
# getting submodel  confusion matrix
